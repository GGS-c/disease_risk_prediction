# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.ravel()

# Visualize distributions of key features
features_to_plot = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak', 'target']

for idx, feature in enumerate(features_to_plot):
    axes[idx].hist(df[feature], bins=20, edgecolor='black', color='steelblue')
    axes[idx].set_xlabel(feature.capitalize())
    axes[idx].set_ylabel('Frequency')
    axes[idx].set_title(f'{feature.capitalize()} Distribution')
    axes[idx].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('../outputs/plots/cp_vs_target.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig, axes = plt.subplots(2, 3, figsize=(15, 10))
#       2 axes = axes.ravel()
#       4 # Visualize distributions of key features
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## 7. Feature Distributions

# %%
plt.figure(figsize=(12, 10))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm', square=True)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.savefig('../outputs/plots/heatmap.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6. Correlation Analysis

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Age Distribution
axes[0].hist(df['age'], bins=20, edgecolor='black', color='skyblue')
axes[0].set_xlabel('Age')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Age Distribution')
axes[0].grid(True, alpha=0.3)

# Chest Pain Type vs Target
cp_target = df.groupby('cp')['target'].value_counts().unstack()
cp_target.plot(kind='bar', ax=axes[1])
axes[1].set_xlabel('Chest Pain Type')
axes[1].set_ylabel('Count')
axes[1].set_title('Chest Pain Type vs Heart Disease')
axes[1].legend(['No Disease', 'Disease'])

plt.tight_layout()
plt.savefig('../outputs/plots/age_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5. Exploratory Visualizations

# %%
print("Missing Values:")
print(df.isnull().sum())
print("\nTotal Missing Values:", df.isnull().sum().sum())

# %% [markdown]
# ## 4. Handle Missing Values

# %%
df.describe()

# %% [markdown]
# ## 3. Statistical Summary

# %%
df.info()
print("\nColumn Names:", df.columns.tolist())

# %%
print("Dataset Shape:", df.shape)
print("\nFirst few rows:")
print(df.head())

# %% [markdown]
# ## 2. Data Overview and Info

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('../data/heart.csv')
print("Dataset loaded successfully!")

# %% [markdown]
# ## 1. Import Libraries and Load Data

# %% [markdown]
# # Exploratory Data Analysis: Heart Disease Dataset
# This notebook performs exploratory data analysis on the heart disease dataset to understand patterns and relationships.
